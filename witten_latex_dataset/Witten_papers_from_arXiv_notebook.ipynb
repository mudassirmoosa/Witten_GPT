# %%
# !pip install arxiv pdfplumber requests
from witten_papers_from_arxiv import *
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 70.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 80.0 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=139b7ce5c64188d2f0cf0d9899be875cd90572b0589634fff00ea50e71de9f24
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# ...

# %%
scraper = WittenLatexScraper("witten_latex_dataset")

# Run for all papers (this will take a while!)
scraper.run_scraper()

print("\nDataset structure:")
print("├── metadata.json (paper metadata + source info)")
print("├── latex_sources/ (individual paper LaTeX files)")
print("└── witten_latex_dataset.txt (single training file with all LaTeX)")
# Out:
# Searching for Edward Witten's papers...
# Found: Supercurrents and (Partial) Supersymmetry in Adjoint QCD$_2$ and Its Generalizations (2025)
# Found: Localization of strings on group manifolds (2025)
# Found: Bras and Kets in Euclidean Path Integrals (2025)
# Found: Introduction to Black Hole Thermodynamics (2024)
# Found: Algebras and states in super-JT gravity (2024)
# Found: Instantons and the Large N=4 Algebra (2024)
# Found: Scale and Conformal Invariance in 2d Sigma Models, with an Application to N=4 Supersymmetry (2024)
# Found: Liouville Theory: An Introduction to Rigorous Approaches (2024)
# Found: A Background Independent Algebra in Quantum Gravity (2023)
# Found: $N=2$ JT Supergravity and Matrix Models (2023)
# Found: Anomalies and Nonsupersymmetric D-Branes (2023)
# Found: The Timelike Tube Theorem in Curved Spacetime (2023)
# Found: Algebras, Regions, and Observers (2023)
# Found: Analytic states in quantum field theory on curved spacetimes (2023)
# ...

# %%
# Create splitter
splitter = LatexDatasetSplitter(
    dataset_file="witten_latex_dataset/witten_latex_dataset.txt"
)

# Create splits with your proposed ratios
splitter.create_splits(
    train_ratio=0.70,
    val_ratio=0.10,
    test_ratio=0.20,
    format_type="latex_only"  # or "with_metadata"
)
# Out:
# Creating splits with ratios - Train: 70.0%, Val: 10.0%, Test: 20.0%
# Parsing papers from witten_latex_dataset/witten_latex_dataset.txt...
# Found 103 papers with LaTeX content
# Papers by decade: [('2020s', 33), ('2010s', 55), ('2000s', 15)]
#   2020s: 23 train, 3 val, 7 test
#   2010s: 38 train, 5 val, 12 test
#   2000s: 10 train, 1 val, 4 test
#
# Split results:
#   Train: 71 papers (68.9%)
#   Val: 9 papers (8.7%)
#   Test: 23 papers (22.3%)
#
# Saving splits to witten_latex_dataset/splits/
#   train: 71 papers, 15,056,938 chars, 2,066,373 words
#   val: 9 papers, 1,724,143 chars, 246,103 words
#   test: 23 papers, 5,108,794 chars, 724,109 words
#
# Total dataset statistics:
#   Total: 21,889,875 characters
#   Train: 15,056,938 chars (68.8%)
#   Val: 1,724,143 chars (7.9%)
#   Test: 5,108,794 chars (23.3%)
#
# Split metadata saved to witten_latex_dataset/splits/split_info.json
# Files created:
#   - train.txt
#   - val.txt
#   - test.txt
